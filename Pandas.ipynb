# %%
import pandas as pd

# %%
#2 main datatypses
car_type = pd.Series(["Toyata", "Nissan", "Honda"])
car_type
car_color =pd.Series(["Blue", "Red", "Black"])
car_color
car_data =pd.DataFrame({"MADE": car_type, "Color": car_color})
car_data

# %%
#import dataframe
car_sales = pd.read_csv("car-sales.csv")
car_sales

# %%
#expecting
car_sales.to_csv("export_car-sales.csv", index = False)
car_sales

# %% [markdown]
# # Describe data

# %%
#attribute
car_sales.dtypes
#function
car_sales.to_csv()

# %%
car_sales.info()

# %%
len(car_sales)

# %% [markdown]
# # View and select data

# %%
car_sales.head()

# %%
car_sales.tail()

# %%
#.loc & .iloc
##.loc refers to index and .iloc refers to position
car_sales.loc[6]

# %%
car_sales.iloc[2]

# %%
car_sales.Make

# %%
car_sales[car_sales["Make"] == "Toyota"]

# %%
car_sales[car_sales["Odometer (KM)"] > 90000]

# %%
#Comparing 2 columns
pd.crosstab(car_sales["Make"], car_sales["Doors"] )

# %%
#Groupby
car_sales.groupby(["Make"]).mean()

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\]','').astype(int)

# %%
car_sales["Price"].plot()

# %% [markdown]
# # Manipulating Data

# %%
#convert dataset to lower case
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
#column from series
seats_column = pd.Series([5,5,5,5,5])

#New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    NaN
# 6   honda   Blue          45698      4   $7,500.00    NaN
# 7   honda   Blue          54738      4   $7,000.00    NaN
# 8  toyota  White          60000      4   $6,250.00    NaN
# 9  nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales['Seats'].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    5.0
# 6   honda   Blue          45698      4   $7,500.00    5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0
# 8  toyota  White          60000      4   $6,250.00    5.0
# 9  nissan  White          31600      4   $9,700.00    5.0

# %%
#Column from python list
fuel_economy =[7.4,9.0,5.6,4.7, 5.5, 3.3,7.4,9.0,5.6,4.7]
car_sales['Fuel Per 10KM'] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 10KM
# 0  toyota  White         150043      4   $4,000.00    5.0            7.4
# 1   honda    Red          87899      4   $5,000.00    5.0            9.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0            5.6
# 3     bmw  Black          11179      5  $22,000.00    5.0            4.7
# 4  nissan  White         213095      4   $3,500.00    5.0            5.5
# 5  toyota  Green          99213      4   $4,500.00    5.0            3.3
# 6   honda   Blue          45698      4   $7,500.00    5.0            7.4
# 7   honda   Blue          54738      4   $7,000.00    5.0            9.0
# 8  toyota  White          60000      4   $6,250.00    5.0            5.6
# 9  nissan  White          31600      4   $9,700.00    5.0            4.7

# %%
car_sales['Total fuel used (L)'] = car_sales["Odometer (KM)"]/100 *car_sales["Fuel Per 10KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 10KM  \
# 0  toyota  White         150043      4   $4,000.00    5.0            7.4
# 1   honda    Red          87899      4   $5,000.00    5.0            9.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0            5.6
# 3     bmw  Black          11179      5  $22,000.00    5.0            4.7
# 4  nissan  White         213095      4   $3,500.00    5.0            5.5
# 5  toyota  Green          99213      4   $4,500.00    5.0            3.3
# 6   honda   Blue          45698      4   $7,500.00    5.0            7.4
# 7   honda   Blue          54738      4   $7,000.00    5.0            9.0
# 8  toyota  White          60000      4   $6,250.00    5.0            5.6
# 9  nissan  White          31600      4   $9,700.00    5.0            4.7
#
#    Total fuel used  Passed Passed Road Safety  Total fuel used (L)
# 0        11103.182                       True            11103.182
# ...

# %%
#create a column from a single value
car_sales ["Passed Passed Road Safety"] = True
car_sales.dtypes
# Out:
# Make                          object
# Colour                        object
# Odometer (KM)                  int64
# Doors                          int64
# Price                         object
# Seats                        float64
# Fuel Per 10KM                float64
# Total fuel used              float64
# Passed Passed Road Safety       bool
# Total fuel used (L)          float64
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 10KM  \
# 0  toyota  White         150043      4   $4,000.00    5.0            7.4
# 1   honda    Red          87899      4   $5,000.00    5.0            9.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0            5.6
# 3     bmw  Black          11179      5  $22,000.00    5.0            4.7
# 4  nissan  White         213095      4   $3,500.00    5.0            5.5
# 5  toyota  Green          99213      4   $4,500.00    5.0            3.3
# 6   honda   Blue          45698      4   $7,500.00    5.0            7.4
# 7   honda   Blue          54738      4   $7,000.00    5.0            9.0
# 8  toyota  White          60000      4   $6,250.00    5.0            5.6
# 9  nissan  White          31600      4   $9,700.00    5.0            4.7
#
#    Total fuel used  Passed Passed Road Safety  Total fuel used (L)
# 0        11103.182                       True            11103.182
# ...

# %%
#To remove a column
car_sales = car_sales.drop("Total fuel used (L)", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 10KM  \
# 0  toyota  White         150043      4   $4,000.00    5.0            7.4
# 1   honda    Red          87899      4   $5,000.00    5.0            9.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0            5.6
# 3     bmw  Black          11179      5  $22,000.00    5.0            4.7
# 4  nissan  White         213095      4   $3,500.00    5.0            5.5
# 5  toyota  Green          99213      4   $4,500.00    5.0            3.3
# 6   honda   Blue          45698      4   $7,500.00    5.0            7.4
# 7   honda   Blue          54738      4   $7,000.00    5.0            9.0
# 8  toyota  White          60000      4   $6,250.00    5.0            5.6
# 9  nissan  White          31600      4   $9,700.00    5.0            4.7
#
#    Total fuel used  Passed Passed Road Safety
# 0        11103.182                       True
# 1         7910.910                       True
# ...

# %%
#shuffle the dataset(mix it up 1=100% )
car_sales.sample(frac =1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 10KM  \
# 1   honda    Red          87899      4   $5,000.00    5.0            9.0
# 8  toyota  White          60000      4   $6,250.00    5.0            5.6
# 4  nissan  White         213095      4   $3,500.00    5.0            5.5
# 0  toyota  White         150043      4   $4,000.00    5.0            7.4
# 2  toyota   Blue          32549      3   $7,000.00    5.0            5.6
# 7   honda   Blue          54738      4   $7,000.00    5.0            9.0
# 6   honda   Blue          45698      4   $7,500.00    5.0            7.4
# 3     bmw  Black          11179      5  $22,000.00    5.0            4.7
# 9  nissan  White          31600      4   $9,700.00    5.0            4.7
# 5  toyota  Green          99213      4   $4,500.00    5.0            3.3
#
#    Total fuel used  Passed Passed Road Safety
# 1         7910.910                       True
# 8         3360.000                       True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac =1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 10KM  \
# 2  toyota   Blue          32549      3   $7,000.00    5.0            5.6
# 6   honda   Blue          45698      4   $7,500.00    5.0            7.4
# 1   honda    Red          87899      4   $5,000.00    5.0            9.0
# 7   honda   Blue          54738      4   $7,000.00    5.0            9.0
# 9  nissan  White          31600      4   $9,700.00    5.0            4.7
# 8  toyota  White          60000      4   $6,250.00    5.0            5.6
# 3     bmw  Black          11179      5  $22,000.00    5.0            4.7
# 0  toyota  White         150043      4   $4,000.00    5.0            7.4
# 4  nissan  White         213095      4   $3,500.00    5.0            5.5
# 5  toyota  Green          99213      4   $4,500.00    5.0            3.3
#
#    Total fuel used  Passed Passed Road Safety
# 2         1822.744                       True
# 6         3381.652                       True
# ...

# %%
#practice on just 20% of the total dataset
car_sales_shuffled.sample(frac=.20)
# Out:
#     Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel Per 10KM  \
# 6  honda   Blue          45698      4  $7,500.00    5.0            7.4
# 7  honda   Blue          54738      4  $7,000.00    5.0            9.0
#
#    Total fuel used  Passed Passed Road Safety
# 6         3381.652                       True
# 7         4926.420                       True

# %%
#covert Odometer from KM to miles and assign back to the Odometer column
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 10KM  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0            7.4
# 1   honda    Red      54936.875      4   $5,000.00    5.0            9.0
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0            5.6
# 3     bmw  Black       6986.875      5  $22,000.00    5.0            4.7
# 4  nissan  White     133184.375      4   $3,500.00    5.0            5.5
# 5  toyota  Green      62008.125      4   $4,500.00    5.0            3.3
# 6   honda   Blue      28561.250      4   $7,500.00    5.0            7.4
# 7   honda   Blue      34211.250      4   $7,000.00    5.0            9.0
# 8  toyota  White      37500.000      4   $6,250.00    5.0            5.6
# 9  nissan  White      19750.000      4   $9,700.00    5.0            4.7
#
#    Total fuel used  Passed Passed Road Safety
# 0        11103.182                       True
# 1         7910.910                       True
# ...
