# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use('ggplot');

plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([3,4,6,1,23]);

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.plot(x, y);

# %%
#1st method
fig=plt.figure()#creates a figure
ax = fig.add_subplot()#add some axes
plt.show()

# %%
#2st method
fig=plt.figure()#creates a figure
ax = fig.add_axes([2,3,1,1])#add some axes
ax.plot(x,y)
plt.show()

# %%
#3st method

fig, ax = plt.subplots()
ax.plot(x,y);

# %%
#prepare mdata
x =[2,3]
y =[0.1,.2]

#Set up the mplot
fig, ax = plt.subplots(figsize=(5,5))

#plot data
ax.plot(x,y)

#customiz data
ax.set(title="Simple Plot",
     xlabel="X-axis",
     ylabel ="Y-axis")

#Save and show plot
fig.savefig("./images/Sample-plot.png")

# %% [markdown]
# # making numbers with numpy arrays

# %%
#Line plot
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig, ax=plt.subplots()
ax.plot(x, x**5);

# %%
#scater plot
fig, ax=plt.subplots()
ax.scatter(x, x**5);

# %%
fig, ax=plt.subplots()
ax.scatter(x, np.sin(x));

# %%
#make a plot from dictionary
drinks_prices ={"Sodar": 15,
               "Win": 9,
               "Liqour": 13}
fig, ax =plt.subplots()
ax.bar(drinks_prices.keys(), drinks_prices.values())
ax.set(title="Drinks Price Store",
     xlabel="Drink",
     ylabel="Price");
ax.set_facecolor('yellow')

# %%
#make it horizontal

fig, ax =plt.subplots()
ax.barh(list(drinks_prices.keys()), list(drinks_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
#Histogram
x = np.random.randn(10000)
fig, ax=plt.subplots()
ax.hist(x);

# %%
#subplots
fig, ((x1,x2),(x3,x4)) =plt.subplots(nrows=2,
                                    ncols=2,
                                    figsize=(10,5));
x1.hist(x)
x4.plot(x)
x2.barh(list(drinks_prices.keys()), list(drinks_prices.values()))
x3.scatter(np.random.random(30), np.random.random(30))

# %%
##Ploting from Pandas DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts =pd.Series(np.random.randn(1000),
             index=pd.date_range("1/1/2020", periods=1000))
ts =ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
##clean data by removing the $,. symbols
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
# /var/folders/t0/tq9tshpn0fjd9s0gdlthdkz40000gp/T/ipykernel_95711/2815017153.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"]=car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
#add sales date
car_sales["Sales Date"]=pd.date_range("1/1/2022", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10

# %%
car_sales["Total Sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500
# 5  Toyota  Green          99213      4   4500 2022-01-06        46000
# 6   Honda   Blue          45698      4   7500 2022-01-07        53500
# 7   Honda   Blue          54738      4   7000 2022-01-08        60500
# 8  Toyota  White          60000      4   6250 2022-01-09        66750
# 9  Nissan  White          31600      4   9700 2022-01-10        76450

# %%
#lets plote the total sales
car_sales.plot(x="Sales Date", y="Total Sales");

# %%
##convert  the price coln to int
car_sales["Price"]=car_sales["Price"].astype(int)

car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
##Do a bargraph

x = np.random.rand(10,4)
x
#make it a dataframe
df=pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.022402  0.927806  0.232497  0.927534
# 1  0.907100  0.322879  0.035968  0.120913
# 2  0.413953  0.002183  0.934324  0.318418
# 3  0.818775  0.407773  0.507898  0.364097
# 4  0.841224  0.038339  0.207188  0.009920
# 5  0.482384  0.592985  0.669220  0.326794
# 6  0.273299  0.447087  0.413261  0.924595
# 7  0.451578  0.543488  0.103128  0.438382
# 8  0.540379  0.513013  0.550514  0.342641
# 9  0.699066  0.551951  0.434691  0.875480

# %%
df.plot.bar();

# %%
car_sales.plot.hist(bins=10);

# %%
car_sales.plot(x="Make", y="Odometer (KM)",kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
heart_disease=pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10, 35),subplots=True);

# %%
over_50 =heart_disease[heart_disease ["age"]>50]
len(over_50)
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
over_50.plot(kind="scatter",
            x="age",
            y='chol',
            c='target');

# %%
#OO mix with pyplot method
fix, ax=plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
            x="age",
            y='chol',
            c='target',
            ax=ax);
#ax.set_xlim([45,100])

# %%
##OO method
fig, ax =plt.subplots(figsize=(10,6))

#plot data
scatter =ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])
#Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
      xlabel="Age",
      ylabel="Cholesterol")

#add legend
ax.legend(*scatter.legend_elements(), title="Target");
#add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle='--');

# %%
##OO method
fig, (ax0, ax1) =plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,6),
                              sharex=True)

#plot data ax0
scatter =ax0.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap='winter')
#Customize the plot
ax0.set(title="Heart Disease and Cholesterol Levels",
      ylabel="Cholesterol")
ax0.set_xlim(50, 80)

#add legend
ax0.legend(*scatter.legend_elements(), title="Target");
#add a horizontal line
ax0.axhline(over_50["chol"].mean(),
          linestyle='--');


#plot data ax1
scatter =ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"],
                     cmap=('winter'))
#Customize the plot
ax1.set(title="Heart Disease and Max Heart Rate",
         xlabel="Age",
      ylabel="Max Heart Rate")
ax1.set_xlim(50, 80)
#add legend
ax1.legend(*scatter.legend_elements(), title="Target");
#add a horizontal line
ax1.axhline(over_50["chol"].mean(),
          linestyle='--');

#add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %%
#Styling plots
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
fig.savefig("Heart_disease_Analysis")
